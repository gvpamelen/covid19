# %% [markdown]
# # Assess Covid-19 data
# ***

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#manual_processing">Manual Processing (only confirmed)</a></li>
# <li><a href="#automated_processing">Automated Processingg (all data)</a></li>
# <li><a href="#sqlite">Store clean data in SQLite DB</a></li>
# </ul>

# %%
# !pip install sqlalchemy ipython-sql
# Out:
# Requirement already satisfied: sqlalchemy in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (1.3.16)
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython-sql) (1.14.0)
# Collecting sqlparse
#   Downloading sqlparse-0.3.1-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.8 MB/s eta 0:00:011
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython-sql) (7.14.0)
# Processing /Users/gijsvanpamelen/Library/Caches/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606/prettytable-0.7.2-cp37-none-any.whl
# Requirement already satisfied: decorator in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: backcall in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.17.0)
# Requirement already satisfied: pygments in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.6.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (40.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (3.0.5)
# Requirement already satisfied: pickleshare in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: parso>=0.7.0 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/gijsvanpamelen/projects/covid19/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.9)
# Could not build wheels for sqlalchemy, since package 'wheel' is not installed.
# Could not build wheels for six, since package 'wheel' is not installed.
# Could not build wheels for ipython-genutils, since package 'wheel' is not installed.
# Could not build wheels for ipython, since package 'wheel' is not installed.
# Could not build wheels for decorator, since package 'wheel' is not installed.
# Could not build wheels for backcall, since package 'wheel' is not installed.
# Could not build wheels for traitlets, since package 'wheel' is not installed.
# Could not build wheels for jedi, since package 'wheel' is not installed.
# Could not build wheels for pygments, since package 'wheel' is not installed.
# Could not build wheels for pexpect, since package 'wheel' is not installed.
# Could not build wheels for appnope, since package 'wheel' is not installed.
# Could not build wheels for setuptools, since package 'wheel' is not installed.
# Could not build wheels for prompt-toolkit, since package 'wheel' is not installed.
# Could not build wheels for pickleshare, since package 'wheel' is not installed.
# Could not build wheels for parso, since package 'wheel' is not installed.
# Could not build wheels for ptyprocess, since package 'wheel' is not installed.
# Could not build wheels for wcwidth, since package 'wheel' is not installed.
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.0 prettytable-0.7.2 sqlparse-0.3.1

# %%
from datetime import date, datetime, timedelta

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# function for cleaning
from src.data.clean_dataset import cleanData
cd = cleanData()

from sqlalchemy import create_engine
# %load_ext sql

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <a id='manual_processing'></a>
# ## 1. Manual Processing
# ***

# %%
df = pd.read_csv('../data/raw/global_confirmed.csv')
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  \
# 0        0        0        0  ...     1828     1939     2171    2335    2469
# 1        0        0        0  ...      750      766      773     782     789
# 2        0        0        0  ...     3649     3848     4006    4154    4295
# 3        0        0        0  ...      743      743      745     745     747
# 4        0        0        0  ...       27       27       27      30      35
#
#    5/3/20  5/4/20  5/5/20  5/6/20  5/7/20
# 0    2704    2894    3224    3392    3563
# 1     795     803     820     832     842
# 2    4474    4648    4838    4997    5182
# 3     748     750     751     751     752
# 4      35      35      36      36      36
#
# [5 rows x 111 columns]

# %% [markdown]
# #### Rename Columns
# Change to all lower-case and single terms.

# %%
df.rename(columns = {'Country/Region' : 'country',
                     'Province/State' : 'state',
                     'Lat' : 'lat',
                     'Long' : 'long'}, inplace=True)

# check
df.head(2)
# Out:
#   state      country      lat     long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0   NaN  Afghanistan  33.0000  65.0000        0        0        0        0
# 1   NaN      Albania  41.1533  20.1683        0        0        0        0
#
#    1/26/20  1/27/20  ...  4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20  \
# 0        0        0  ...     1828     1939     2171    2335    2469    2704
# 1        0        0  ...      750      766      773     782     789     795
#
#    5/4/20  5/5/20  5/6/20  5/7/20
# 0    2894    3224    3392    3563
# 1     803     820     832     842
#
# [2 rows x 111 columns]

# %% [markdown]
# #### Get separate df for state, country, lat, long
# ***
# Capture country, state (included since lat/long data is on state level), lat, long

# %%
country_data = df[['country','state','lat','long']]
country_data.head()
# Out:
#        country state      lat     long
# 0  Afghanistan   NaN  33.0000  65.0000
# 1      Albania   NaN  41.1533  20.1683
# 2      Algeria   NaN  28.0339   1.6596
# 3      Andorra   NaN  42.5063   1.5218
# 4       Angola   NaN -11.2027  17.8739

# %% [markdown]
# #### Aggregate data per country
# ***
# * drop lat, long columns (no aggregation needed here)
# * Sum daily values over all provinces for a country

# %%
# drop lat/long
df.drop(['lat','long'], axis=1, inplace=True)
df.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0   NaN  Afghanistan        0        0        0        0        0        0
# 1   NaN      Albania        0        0        0        0        0        0
# 2   NaN      Algeria        0        0        0        0        0        0
# 3   NaN      Andorra        0        0        0        0        0        0
# 4   NaN       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20  \
# 0        0        0  ...     1828     1939     2171    2335    2469    2704
# 1        0        0  ...      750      766      773     782     789     795
# 2        0        0  ...     3649     3848     4006    4154    4295    4474
# 3        0        0  ...      743      743      745     745     747     748
# 4        0        0  ...       27       27       27      30      35      35
#
#    5/4/20  5/5/20  5/6/20  5/7/20
# 0    2894    3224    3392    3563
# 1     803     820     832     842
# 2    4648    4838    4997    5182
# 3     750     751     751     752
# 4      35      36      36      36
#
# [5 rows x 109 columns]

# %%
# group by coutry and store in new df
df_country = df.groupby('country').sum().reset_index()

# check
assert df[df['country']=='Australia']['5/7/20'].sum() == df_country[df_country['country']=='Australia']['5/7/20'].iloc[0]

# %%
df_country.head()
# Out:
#        country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0  Afghanistan        0        0        0        0        0        0        0
# 1      Albania        0        0        0        0        0        0        0
# 2      Algeria        0        0        0        0        0        0        0
# 3      Andorra        0        0        0        0        0        0        0
# 4       Angola        0        0        0        0        0        0        0
#
#    1/29/20  1/30/20  ...  4/28/20  4/29/20  4/30/20  5/1/20  5/2/20  5/3/20  \
# 0        0        0  ...     1828     1939     2171    2335    2469    2704
# 1        0        0  ...      750      766      773     782     789     795
# 2        0        0  ...     3649     3848     4006    4154    4295    4474
# 3        0        0  ...      743      743      745     745     747     748
# 4        0        0  ...       27       27       27      30      35      35
#
#    5/4/20  5/5/20  5/6/20  5/7/20
# 0    2894    3224    3392    3563
# 1     803     820     832     842
# 2    4648    4838    4997    5182
# 3     750     751     751     752
# 4      35      36      36      36
#
# [5 rows x 108 columns]

# %% [markdown]
# #### Move dates to a single row
# Transpose table - using 'melt' function

# %%
df2 = df_country.melt(id_vars=["country"], 
                      var_name="date", 
                      value_name="confirmed")

# check
assert df2[(df2['country']=='Australia') & (df2['date']=='5/7/20')]['confirmed'].iloc[0] ==df_country[df_country['country']=='Australia']['5/7/20'].iloc[0]

# view
df2.head()
# Out:
#        country     date  confirmed
# 0  Afghanistan  1/22/20          0
# 1      Albania  1/22/20          0
# 2      Algeria  1/22/20          0
# 3      Andorra  1/22/20          0
# 4       Angola  1/22/20          0

# %% [markdown]
# #### Change date format
# * Use string processing to change format to `YYYY-MM-DD`
# * change data-format to datetime

# %%
# extract individual date elements
date_parts = df2.date.str.split('/', expand=True) # month
date_parts.columns = ['month','day','year']

# pad month and day to 2 digits
date_parts.month = date_parts.month.str.pad(width=2, side='left',fillchar='0')
date_parts.day = date_parts.day.str.pad(width=2, side='left',fillchar='0')

# add '20' to year
date_parts.year = np.repeat('20',len(date_parts)) + date_parts.year

# get the full date
full_date = date_parts['year'] + '-' + date_parts['month'] + '-' + date_parts['day']

# %%
# replace date column with clean date
df2['date'] = full_date
df2['date'] = pd.to_datetime(df2['date'], format="%Y-%m-%d")

# %%
df2.head()
# Out:
#        country       date  confirmed
# 0  Afghanistan 2020-01-22          0
# 1      Albania 2020-01-22          0
# 2      Algeria 2020-01-22          0
# 3      Andorra 2020-01-22          0
# 4       Angola 2020-01-22          0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20009 entries, 0 to 20008
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    20009 non-null  object
#  1   date       20009 non-null  datetime64[ns]
#  2   confirmed  20009 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 469.1+ KB

# %% [markdown]
# #### Change country 'US' to 'United States'
# replace US with united states

# %%
df2.replace('US','United States', inplace=True)

# %%
# check - should
assert len(df2[df2['country']=='US']) == 0

# visual check
df2[df2['country']=='United States']
# Out:
#              country       date  confirmed
# 173    United States 2020-01-22          1
# 360    United States 2020-01-23          1
# 547    United States 2020-01-24          2
# 734    United States 2020-01-25          2
# 921    United States 2020-01-26          5
# ...              ...        ...        ...
# 19247  United States 2020-05-03    1158040
# 19434  United States 2020-05-04    1180375
# 19621  United States 2020-05-05    1204351
# 19808  United States 2020-05-06    1228603
# 19995  United States 2020-05-07    1257023
#
# [107 rows x 3 columns]

# %% [markdown]
# <a id='automated_processing'></a>
# ## 2. Automated Processing
# ***
# * Automate the steps above
# * Apply to `confirmed` (above), `deaths` and `recovered` (all have same structure)
# * Combine dataframes to get 2 outputs: country (country, state, lat, long) and covid (country, date, confirmed, death, recovered)

# %% [markdown]
# #### confirmed

# %%
# collect raw data
confirmed_raw = pd.read_csv('../data/raw/global_confirmed.csv')

# clean the data
confirmed_cleaned = cd.cleanData(confirmed_raw,'confirmed')
confirmed_cleaned.head(2)
# Out:
#        country       date  confirmed
# 0  Afghanistan 2020-01-22          0
# 1      Albania 2020-01-22          0

# %% [markdown]
# #### deaths

# %%
# collect raw data
death_raw = pd.read_csv('../data/raw/global_deaths.csv')

# clean the data
death_cleaned = cd.cleanData(death_raw,'death')
death_cleaned.head(2)
# Out:
#        country       date  death
# 0  Afghanistan 2020-01-22      0
# 1      Albania 2020-01-22      0

# %% [markdown]
# #### recovered

# %%
# collect raw data
recovered_raw = pd.read_csv('../data/raw/global_recovered.csv')

# clean the data
recovered_cleaned = cd.cleanData(recovered_raw,'recovered')
recovered_cleaned.head(2)
# Out:
#        country       date  recovered
# 0  Afghanistan 2020-01-22          0
# 1      Albania 2020-01-22          0

# %% [markdown]
# #### combine dataframes

# %%
confirmed_cleaned.shape
# Out:
# (20009, 3)

# %%
death_cleaned.shape
# Out:
# (20009, 3)

# %%
recovered_cleaned.shape
# Out:
# (20009, 3)

# %%
# combine the dataframes
combined = confirmed_cleaned.merge(death_cleaned, on = ['country','date'], how='inner').merge(recovered_cleaned, on = ['country','date'], how='inner')
combined.tail()
# Out:
#                   country       date  confirmed  death  recovered
# 20004  West Bank and Gaza 2020-05-07        375      2        176
# 20005      Western Sahara 2020-05-07          6      0          5
# 20006               Yemen 2020-05-07         25      5          1
# 20007              Zambia 2020-05-07        153      4        103
# 20008            Zimbabwe 2020-05-07         34      4          5

# %%
# create the country dataframe
country_data = confirmed_raw[['Province/State','Country/Region','Lat','Long']]
country_data.columns = ['country','state','lat','long']
country_data.head()
# Out:
#   country        state      lat     long
# 0     NaN  Afghanistan  33.0000  65.0000
# 1     NaN      Albania  41.1533  20.1683
# 2     NaN      Algeria  28.0339   1.6596
# 3     NaN      Andorra  42.5063   1.5218
# 4     NaN       Angola -11.2027  17.8739

# %% [markdown]
# <a id='sqlite'></a>
# ## 3. Store dataframes in SQLite DB
# ***
# From above, we need to store combined and country data

# %% [markdown]
# #### create DB

# %%
# database parameters
driver = 'sqlite'
filename = '../data/processed/covid.sqlite'
driver+":///"+filename
# Out:
# 'sqlite:///../data/processed/covid.sqlite'

# %%
# make the connection
engine = create_engine(driver+":///"+filename)
connection = engine.connect()

# %%
# %sql sqlite:///../data/processed/covid.sqlite

# %%
# %%sql
# -- if there are tables - we need to drop them first otherwise we'll duplicate.
# DROP TABLE IF EXISTS stats;
# DROP TABLE IF EXISTS country;
# Out:
#  * sqlite:///../data/processed/covid.sqlite
# Done.
# Done.
# []

# %%
# check for a proper connection - we expect no tables to be present yet!
print(engine.table_names())
# Out:
# []

# %% [markdown]
# #### load tables

# %%
# load tables in DB
combined.to_sql('stats', con = engine, if_exists = 'append', index=False, chunksize = 1000)
country_data.to_sql('country', con = engine, if_exists = 'append', index=False, chunksize = 1000)

# %%
# check stats table
stats_len = %sql SELECT COUNT(*) FROM stats
assert len(combined) == stats_len[0][0]

# check country table
country_len = %sql SELECT COUNT(*) FROM country
assert len(country_data) == country_len[0][0]
# Out:
#  * sqlite:///../data/processed/covid.sqlite
# Done.
#  * sqlite:///../data/processed/covid.sqlite
# Done.

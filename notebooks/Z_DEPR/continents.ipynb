# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# function for querying db
from src.data.query_db import queryDB
qdb = queryDB('sqlite','../data/processed/covid.sqlite')
# Out:
# sqlite:///../data/processed/covid.sqlite

# %% [markdown]
# ## 1. Load Data
# ***
# We've already collected country data on three levels in `data/raw`. We'll now take the most granular set (where we have the most countries) and captured the country-name and continent.

# %% [markdown]
# #### country - continent mapping

# %%
path = '../data/raw'
countries = gpd.read_file(path + '/' + 'ne_10m_admin_0_countries.shp')[['ADMIN','CONTINENT']]
countries.head(5)
# Out:
#        ADMIN      CONTINENT
# 0  Indonesia           Asia
# 1   Malaysia           Asia
# 2      Chile  South America
# 3    Bolivia  South America
# 4       Peru  South America

# %%
countries.groupby('CONTINENT').size()
# Out:
# CONTINENT
# Africa                     54
# Antarctica                  1
# Asia                       59
# Europe                     51
# North America              42
# Oceania                    26
# Seven seas (open ocean)     9
# South America              13
# dtype: int64

# %% [markdown]
# #### our current countries
# As this data is static, we'll add it to the populations table

# %%
qdb.engine.table_names()
# Out:
# ['country', 'daily_stats', 'exp_stats', 'populations', 'stats']

# %%
query = """
    SELECT *
    FROM populations"""

df = qdb.execute_query(query)
df.head()
# Out:
# 235 rows affected
#    rank        country  population  yearly_change_pct  net_change  density  \
# 0     1          China  1439323776               0.39     5540090      153
# 1     2          India  1380004385               0.99    13586631      464
# 2     3  United States   331002651               0.59     1937734       36
# 3     4      Indonesia   273523615               1.07     2898047      151
# 4     5       Pakistan   220892340               2.00     4327022      287
#
#    land_are  migrants  fert_rate  med_age  urban_pop_pct  world_share_pct  \
# 0   9388211 -348399.0        1.7       38             61            18.47
# 1   2973190 -532687.0        2.2       28             35            17.70
# 2   9147420  954806.0        1.8       38             83             4.25
# 3   1811570  -98955.0        2.3       30             56             3.51
# 4    770880 -233379.0        3.6       23             35             2.83
#
#    scaled_pop
# 0     1439.32
# 1     1380.00
# 2      331.00
# 3      273.52
# 4      220.89

# %% [markdown]
# ## 2. Clean
# ***
# Ensure our countries match

# %% [markdown]
# #### 2.1 assessment

# %%
merged = df.merge(countries, left_on = 'country', right_on = 'ADMIN', how = 'outer')

# %%
# missing in population-table

# %%
merged[merged['ADMIN'].isnull()][['country']]
# Out:
#                      country
# 2              United States
# 15                  DR Congo
# 23                  Tanzania
# 85            Czech Republic
# 98                    Serbia
# 103                Hong Kong
# 116                    Congo
# 120       State of Palestine
# 147          North Macedonia
# 155              Timor-Leste
# 158                 Eswatini
# 161                  Réunion
# 166                    Macao
# 175               Guadeloupe
# 177                  Bahamas
# 178               Martinique
# 181            French Guiana
# 185                  Mayotte
# 186    Sao Tome and Principe
# 189          Channel Islands
# 193               Micronesia
# 198      U.S. Virgin Islands
# 211           Faeroe Islands
# 214         Turks and Caicos
# 220    Caribbean Netherlands
# 225          Wallis & Futuna
# 229  Saint Pierre & Miquelon
# 233                  Tokelau
# 234                 Holy See

# %%
# missing from shapefile (match to the above)
merged[merged['country'].isnull()][['ADMIN','CONTINENT']].sort_values('ADMIN')
# Out:
#                                     ADMIN                CONTINENT
# 255          Akrotiri Sovereign Base Area                     Asia
# 268                                 Aland                   Europe
# 256                            Antarctica               Antarctica
# 280           Ashmore and Cartier Islands                  Oceania
# 281          Bajo Nuevo Bank (Petrel Is.)            North America
# 254                   Baykonur Cosmodrome                     Asia
# 271        British Indian Ocean Territory  Seven seas (open ocean)
# 278                     Clipperton Island  Seven seas (open ocean)
# 276                     Coral Sea Islands                  Oceania
# 252                   Cyprus No Mans Area                     Asia
# 241                               Czechia                   Europe
# 240      Democratic Republic of the Congo                   Africa
# 235          Dhekelia Sovereign Base Area                     Asia
# 245                            East Timor                     Asia
# 269                         Faroe Islands                   Europe
# 274        Federated States of Micronesia                  Oceania
# 261   French Southern and Antarctic Lands  Seven seas (open ocean)
# 267                              Guernsey                   Europe
# 264     Heard Island and McDonald Islands  Seven seas (open ocean)
# 249                      Hong Kong S.A.R.                     Asia
# 270              Indian Ocean Territories                     Asia
# 266                                Jersey                   Europe
# 243                                Kosovo                   Europe
# 279                           Macao S.A.R                     Asia
# 242                             Macedonia                   Europe
# 272                        Norfolk Island                  Oceania
# 251                       Northern Cyprus                     Asia
# 236                             Palestine                     Asia
# 260                      Pitcairn Islands                  Oceania
# 244                    Republic of Serbia                   Europe
# 239                 Republic of the Congo                   Africa
# 259             Saint Pierre and Miquelon            North America
# 283                      Scarborough Reef                     Asia
# 282                       Serranilla Bank            North America
# 253                       Siachen Glacier                     Asia
# 238                            Somaliland                   Africa
# 275         South Georgia and the Islands  Seven seas (open ocean)
# 277                       Spratly Islands                     Asia
# 265                 São Tomé and Principe                   Africa
# 257                           The Bahamas            North America
# 258              Turks and Caicos Islands            North America
# 247          US Naval Base Guantanamo Bay            North America
# 237           United Republic of Tanzania                   Africa
# 262  United States Minor Outlying Islands            North America
# 263          United States Virgin Islands            North America
# 248              United States of America            North America
# 250                               Vatican                   Europe
# 273                     Wallis and Futuna                  Oceania
# 246                              eSwatini                   Africa

# %% [markdown]
# #### 2.2 clean data
# Create a translation dict, mapping the current value from the shapfile, to the correct value from our population table.
#
# Note that 'overseas departments' are often not included as a separate country in the shapefile. Examples of this would be Guadeloupe (department of France). We're adding these to their gouvernemental continent, in this case: France.
#
# Arguments could be made to count this with South America as well.

# %%
# translation table - target: current
country_trans = {
     'United States of America' : 'United States',
     'Democratic Republic of the Congo' : 'DR Congo',
     'United Republic of Tanzania' : 'Tanzania',
     'Czechia' : 'Czech Republic',
     'Republic of Serbia' : 'Serbia',
     'Hong Kong S.A.R.' : 'Hong Kong',
     'Republic of the Congo' : 'Congo',
     'Palestine' : 'State of Palestine',
     'Macedonia' : 'North Macedonia',
     'East Timor' : 'Timor-Leste',
     'eSwatini' : 'Eswatini',
     'Macao S.A.R' : 'Macao',
     'The Bahamas' : 'Bahamas',
     'São Tomé and Principe' : 'Sao Tome and Principe',
     'Federated States of Micronesia' : 'Micronesia',
     'United States Virgin Islands' : 'U.S. Virgin Islands',
     'Faroe Islands' : 'Faeroe Islands',
     'Turks and Caicos Islands' : 'Turks and Caicos',
     'Wallis and Futuna' : 'Wallis & Futuna',
     'Saint Pierre and Miquelon' : 'Saint Pierre & Miquelon'}


continent_trans = {
    'Réunion' : 'Europe',
    'Guadeloupe' : 'Europe',
    'Martinique' : 'Europe',
    'French Guiana' : 'Europe',
    'Channel Islands' : 'Europe',
    'Gibraltar' : 'Europe',
    'Caribbean Netherlands' : 'Europe',
    'Mayotte' : 'Europe',
    'Tuvalu' : 'Oceania',
    'Tokelau' : 'Oceania',
    'Holy See' : 'Europe'}

# %%
# map countries
countries['ADMIN'].replace(country_trans, inplace = True)

# %%
merged = df.merge(countries, left_on = 'country', right_on = 'ADMIN', how = 'outer')
merged[merged['ADMIN'].isnull()][['country']]
# Out:
#                    country
# 161                Réunion
# 175             Guadeloupe
# 178             Martinique
# 181          French Guiana
# 185                Mayotte
# 189        Channel Islands
# 220  Caribbean Netherlands
# 233                Tokelau
# 234               Holy See

# %%
# dataframe with the final country - continent mapping
continent_map = pd.DataFrame.from_dict(continent_trans, orient = 'index').reset_index()
continent_map.columns = ['ADMIN', 'CONTINENT']
continent_map
# Out:
#                     ADMIN CONTINENT
# 0                 Réunion    Europe
# 1              Guadeloupe    Europe
# 2              Martinique    Europe
# 3           French Guiana    Europe
# 4         Channel Islands    Europe
# 5               Gibraltar    Europe
# 6   Caribbean Netherlands    Europe
# 7                 Mayotte    Europe
# 8                  Tuvalu   Oceania
# 9                 Tokelau   Oceania
# 10               Holy See    Europe

# %%
# update our countries
countries = countries.append(continent_map)
countries.columns = ['ADMIN','continent']

# check
merged = df.merge(countries, left_on = 'country', right_on = 'ADMIN', how = 'outer')
merged[merged['ADMIN'].isnull()][['country']]
# Out:
# Empty DataFrame
# Columns: [country]
# Index: []

# %%
# final merge
df2 = df.merge(countries, left_on = 'country', right_on = 'ADMIN', how = 'left')
df2.head()
# Out:
#    rank        country  population  yearly_change_pct  net_change  density  \
# 0     1          China  1439323776               0.39     5540090      153
# 1     2          India  1380004385               0.99    13586631      464
# 2     3  United States   331002651               0.59     1937734       36
# 3     4      Indonesia   273523615               1.07     2898047      151
# 4     5       Pakistan   220892340               2.00     4327022      287
#
#    land_are  migrants  fert_rate  med_age  urban_pop_pct  world_share_pct  \
# 0   9388211 -348399.0        1.7       38             61            18.47
# 1   2973190 -532687.0        2.2       28             35            17.70
# 2   9147420  954806.0        1.8       38             83             4.25
# 3   1811570  -98955.0        2.3       30             56             3.51
# 4    770880 -233379.0        3.6       23             35             2.83
#
#    scaled_pop          ADMIN      continent
# 0     1439.32          China           Asia
# 1     1380.00          India           Asia
# 2      331.00  United States  North America
# 3      273.52      Indonesia           Asia
# 4      220.89       Pakistan           Asia

# %%
df2[df2['continent'].isnull()]
# Out:
# Empty DataFrame
# Columns: [rank, country, population, yearly_change_pct, net_change, density, land_are, migrants, fert_rate, med_age, urban_pop_pct, world_share_pct, scaled_pop, ADMIN, continent]
# Index: []

# %% [markdown]
# ## 3. Update Table
# ***

# %%
# update table with new column
query = """
    ALTER TABLE populations
    ADD continent varchar"""

qdb.execute_query(query)
# Out:
# unable to execute query
# ---
# (sqlite3.OperationalError) duplicate column name: continent
# [SQL:
#     ALTER TABLE populations
#     ADD continent varchar]
# (Background on this error at: http://sqlalche.me/e/e3q8)
# ---

# %%
# insert into this column
for i in range(len(df2)):
    query = """
        UPDATE populations
        SET continent = '{}'
        WHERE country = '{}'
        """.format(df2['continent'][i], df2['country'][i])

    qdb.execute_query(query)
# Out:
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---
# unable to execute query
# ---
# This result object does not return rows. It has been closed automatically.
# ---

# %%
q = """SELECT * 
       FROM populations 
       WHERE continent IS NULL LIMIT 5"""
qdb.execute_query(q)
# Out:
# 0 rows affected
# Empty DataFrame
# Columns: [rank, country, population, yearly_change_pct, net_change, density, land_are, migrants, fert_rate, med_age, urban_pop_pct, world_share_pct, scaled_pop, continent]
# Index: []

# %%
# DONE!
